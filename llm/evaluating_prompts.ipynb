# %% [markdown]
# <a href="https://colab.research.google.com/github/CuriousGu/llm_zeroshot_calibration/blob/dev/llm/evaluating_prompts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1.0 - Initial Settings

# %%
# %%capture
# !pip install openai==0.28

# %%
# LLM
import openai

# Data Processing
import pandas as pd
import re

# settings
from google.colab import userdata, drive
from tqdm import tqdm
import os

# %%
# finding folder path
def find_folder(root, target):
  for root, dirs, _ in os.walk(root):
    if target in dirs:
      return os.path.join(root, target)
  return ValueError("None\nDownload the Dataset or change the target Directory")

# %%
drive.mount("/content/drive")

root = "/"
target = "datasets_imdb"
PATH = find_folder(root, target)
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 1.1 - Testing Prompts

# %% [markdown]
# I will test 4 prompts generated by ChatGPT with 15 random users. All of them will be evaluated, so the better one will be used in large scale.

# %% [markdown]
# ## 1.1 - LLM

# %%
openai.api_key = userdata.get('OPENAI_API_KEY')

def request_openai(prompt, openai=openai):

  response = openai.ChatCompletion.create(
      model="gpt-3.5-turbo",
      temperature=0.2,
      max_tokens=300,
      top_p=0.9,
      messages=[
          {
              "role": "system",
              "content": "You are a recommender"
          },
          {
              "role": "user",
              "content": prompt
          }
      ]
  )

  return response['choices'][0]['message']['content']

# %% [markdown]
# ## 1.2 - Reading Data

# %%
headers = ["userId", "movieId", "rating", "timestamp", "title"]
trainset = pd.read_csv(f"{PATH}/refined/train_llm.csv", names=headers)
testset = pd.read_csv(f"{PATH}/refined/test_llm.csv", names=headers)

# %%
users_test = trainset.userId.unique()[:15]
trainset = trainset[trainset.userId.isin(users_test)]

# %%
user_movies_dict = trainset.groupby('userId')['title'].apply(list).to_dict()

# %% [markdown]
# ## 1.3 - Prompts

# %%
testing_prompts = {
  "p1": "Please suggest 15 movies or TV shows. Format the output as follows: 'production (release year)\nproduction (release year)\nproduction (release year)...'",
  "p2": "I'm looking for movies and TV shows, can you provide 15 recommendations released prior to 2015? Please list 15 productions with their release years only in the format: 'production (release year)\nproduction (release year)...'",
  "p3": "Could you recommend some classic movies and TV shows from before 2015? I need the output formatted as follows: 'movie (release year)\ntv show (release year)\nmovie (release year)...'",
  "p4": "I'm interested in discovering older content. Can you suggest 15 movies or TV shows released before 2015? Please list the productions along with their release years only, in the format: 'production (release year)\nproduction (release year)...'"
}

# %% [markdown]
# ## 1.4 - Requesting Recs

# %%
llm_recs = list()

total_iterations = len(testing_prompts) * len(user_movies_dict)
progress_bar = tqdm(total=total_iterations, desc='Progress')

for prompt_id, prompt in testing_prompts.items():
  for k, v in user_movies_dict.items():
    temp_dict = dict()

    movies = "\n".join(v)
    prompt += f"\nI've watched:\n{movies}"
    response = request_openai(prompt)

    temp_dict['prompt_id'] = prompt_id
    temp_dict["response"] = response
    temp_dict["userId"] = k

    llm_recs.append(temp_dict)
    progress_bar.update(1)

progress_bar.close()
# Out:
# Progress: 100%|██████████| 60/60 [03:15<00:00,  3.26s/it]

# %%
df_recs = pd.DataFrame(llm_recs)
df_recs.tail(5)
# Out:
#    prompt_id                                           response  userId
# 55        p4  The recommendations are:\n1. The Shawshank Red...    2854
# 56        p4  The recommendations are:\n1. The Shawshank Red...    3231
# 57        p4  The recommendations are:\n1. The Godfather (19...    3300
# 58        p4  1. The Shawshank Redemption (1994)\n2. Pulp Fi...    7623
# 59        p4  Here are 15 movies or TV shows released before...    7886

# %% [markdown]
# ## 1.5 - Saving Recs

# %%
df_recs.to_csv(f"{PATH}/refined/recs_llm/evaluating_prompts.csv", index=False)

# %% [markdown]
# # 2.0 - Evaluating Better Prompt

# %% [markdown]
# ## 2.1 - Visual Analysis

# %%
df_recs = pd.read_csv(f"{PATH}/refined/recs_llm/evaluating_prompts.csv")

for k in testing_prompts.keys():
  p_recs = df_recs[df_recs.prompt_id == k]['response']
  print(f"\n\n{'#'*10} {k} {'#'*10}\n\n")
  for x in df_recs[df_recs.prompt_id == 'p1']['response']:
    print(x)
# Out:
# ########## p1 ##########
#
#
# The Shawshank Redemption (1994)
# Friends (1994)
# Pulp Fiction (1994)
# The Lion King (1994)
# Forrest Gump (1994)
# The Matrix (1999)
# The Sopranos (1999)
# American Beauty (1999)
# Fight Club (1999)
# The Sixth Sense (1999)
# The Green Mile (1999)
# The Office (UK) (2001)
# The Lord of the Rings: The Fellowship of the Ring (2001)
# Harry Potter and the Sorcerer's Stone (2001)
# Shrek (2001)
# The Princess Bride (1987)
# The Shawshank Redemption (1994)
# Forrest Gump (1994)
# Pulp Fiction (1994)
# The Matrix (1999)
# The Silence of the Lambs (1991)
# Fight Club (1999)
# The Godfather (1972)
# Back to the Future (1985)
# Jurassic Park (1993)
# Friends (1994)
# The X-Files (1993)
# The Simpsons (1989)
# Seinfeld (1989)
# Buffy the Vampire Slayer (1997)
# The Sixth Sense (1999)
# The Matrix (1999)
# American Beauty (1999)
# Fight Club (1999)
# The Green Mile (1999)
# The Shawshank Redemption (1994)
# Pulp Fiction (1994)
# Forrest Gump (1994)
# The Lion King (1994)
# Jurassic Park (1993)
# Friends (1994)
# The X-Files (1993)
# The Simpsons (1989)
# Seinfeld (1989)
# Buffy the Vampire Slayer (1997)
# The Godfather (1972)
# Friends (1994)
# Forrest Gump (1994)
# The Shawshank Redemption (1994)
# Pulp Fiction (1994)
# The Matrix (1999)
# The Silence of the Lambs (1991)
# Seinfeld (1989)
# Jurassic Park (1993)
# The Lion King (1994)
# The Sopranos (1999)
# Titanic (1997)
# The Simpsons (1989)
# Braveheart (1995)
# Home Alone (1990)
# The Godfather (1972)
# Friends (1994)
# The Shawshank Redemption (1994)
# Breaking Bad (2008)
# Forrest Gump (1994)
# The Sopranos (1999)
# Pulp Fiction (1994)
# The Simpsons (1989)
# The Matrix (1999)
# The Silence of the Lambs (1991)
# Jurassic Park (1993)
# Seinfeld (1989)
# Schindler's List (1993)
# The X-Files (1993)
# Titanic (1997)
# The Princess Bride (1987)
# Friends (1994)
# Forrest Gump (1994)
# The X-Files (1993)
# The Lion King (1994)
# Seinfeld (1989)
# Jurassic Park (1993)
# The Simpsons (1989)
# Home Alone (1990)
# The Shawshank Redemption (1994)
# Pulp Fiction (1994)
# The Matrix (1999)
# The
# The Nightmare Before Christmas (1993)
# Schindler's List (1993)
# The Piano (1993)
# The Silence of the Lambs (1991)
# Twin Peaks (1990)
# Goodfellas (1990)
# Home Alone (1990)
# Edward Scissorhands (1990)
# The Princess Bride (1987)
# Friends (1994)
# Forrest Gump (1994)
# The X-Files (1993)
# The Shawshank Redemption (1994)
# Seinfeld (1989)
# Jurassic Park (1993)
# The Simpsons (1989)
# The Silence of the Lambs (1991)
# The Fresh Prince of Bel-Air (1990)
# Pulp Fiction (1994)
# Full House (1987)
# Home Alone (1990)
# The Office (2005)
# Titanic (1997)
# 1. The Godfather (1972)
# 2. Friends (1994)
# 3. Forrest Gump (1994)
# 4. The Shawshank Redemption (1994)
# 5. Seinfeld (1989)
# 6. Pulp Fiction (1994)
# 7. The Simpsons (1989)
# 8. Jurassic Park (1993)
# 9. The Matrix (1999)
# 10. Breaking Bad (2008)
# 11. The Silence of the Lambs (1991)
# 12. The Sopranos (1999)
# 13. Schindler's List (1993)
# 14. The X-Files (1993)
# 15. Goodfellas (1990)
# The Princess Bride (1987)
# Friends (1994)
# Forrest Gump (1994)
# The X-Files (1993)
# The Godfather (1972)
# The Simpsons (1989)
# Jurassic Park (1993)
# Breaking Bad (2008)
# The Shawshank Redemption (1994)
# The Twilight Zone (1959)
# Pulp Fiction (1994)
# Seinfeld (1989)
# Back to the Future (1985)
# The Sopranos (1999)
# The Silence of the Lambs (1991)
# - The Shawshank Redemption (1994)
# - Friends (1994)
# - Pulp Fiction (1994)
# - The Lion King (1994)
# - Forrest Gump (1994)
# - Seinfeld (1989)
# - Jurassic Park (1993)
# - The Matrix (1999)
# - The Silence of the Lambs (1991)
# - The Simpsons (1989)
# - The Godfather (1972)
# - Breaking Bad (2008)
# - Schindler's List (1993)
# - The Sopranos (1999)
# - The Green Mile (1999)
# The Shawshank Redemption (1994)
# Friends (1994)
# Forrest Gump (1994)
# The Lion King (1994)
# Pulp Fiction (1994)
# The Matrix (1999)
# The Sopranos (1999)
# Fight Club (1999)
# The Sixth Sense (1999)
# The Office (UK) (2001)
# The Godfather (1972)
# Breaking Bad (2008)
# Schindler's List (1993)
# The Simpsons (1989)
# Jurassic Park (1993)

# %%
for index, row in df_recs.iterrows():
  movie_name, prompt = row['response'], row['prompt_id']
  print(f"#### {prompt} #### \n{movie_name}\n\n")
# Out:
# #### p1 ####
# The Shawshank Redemption (1994)
# Friends (1994)
# Pulp Fiction (1994)
# The Lion King (1994)
# Forrest Gump (1994)
# The Matrix (1999)
# The Sopranos (1999)
# American Beauty (1999)
# Fight Club (1999)
# The Sixth Sense (1999)
# The Green Mile (1999)
# The Office (UK) (2001)
# The Lord of the Rings: The Fellowship of the Ring (2001)
# Harry Potter and the Sorcerer's Stone (2001)
# Shrek (2001)
#
#
# #### p1 ####
# The Princess Bride (1987)
# The Shawshank Redemption (1994)
# Forrest Gump (1994)
# Pulp Fiction (1994)
# The Matrix (1999)
# The Silence of the Lambs (1991)
# Fight Club (1999)
# The Godfather (1972)
# Back to the Future (1985)
# Jurassic Park (1993)
# Friends (1994)
# The X-Files (1993)
# The Simpsons (1989)
# Seinfeld (1989)
# Buffy the Vampire Slayer (1997)
#
#
# #### p1 ####
# The Sixth Sense (1999)
# The Matrix (1999)
# American Beauty (1999)
# Fight Club (1999)
# The Green Mile (1999)
# The Shawshank Redemption (1994)
# Pulp Fiction (1994)
# Forrest Gump (1994)
# The Lion King (1994)
# Jurassic Park (1993)
# Friends (1994)
# The X-Files (1993)
# The Simpsons (1989)
# Seinfeld (1989)
# Buffy the Vampire Slayer (1997)
#
#
# #### p1 ####
# The Godfather (1972)
# Friends (1994)
# Forrest Gump (1994)
# The Shawshank Redemption (1994)
# Pulp Fiction (1994)
# The Matrix (1999)
# The Silence of the Lambs (1991)
# Seinfeld (1989)
# Jurassic Park (1993)
# The Lion King (1994)
# The Sopranos (1999)
# Titanic (1997)
# The Simpsons (1989)
# Braveheart (1995)
# Home Alone (1990)
#
#
# #### p1 ####
# The Godfather (1972)
# Friends (1994)
# The Shawshank Redemption (1994)
# Breaking Bad (2008)
# Forrest Gump (1994)
# The Sopranos (1999)
# Pulp Fiction (1994)
# The Simpsons (1989)
# The Matrix (1999)
# The Silence of the Lambs (1991)
# Jurassic Park (1993)
# Seinfeld (1989)
# Schindler's List (1993)
# The X-Files (1993)
# Titanic (1997)
#
#
# #### p1 ####
# The Princess Bride (1987)
# Friends (1994)
# Forrest Gump (1994)
# The X-Files (1993)
# The Lion King (1994)
# Seinfeld (1989)
# Jurassic Park (1993)
# The Simpsons (1989)
# Home Alone (1990)
# The Shawshank Redemption (1994)
# Pulp Fiction (1994)
# The Matrix (1999)
# The Godfather (1972)
# Breaking Bad (2008)
# The Silence of the Lambs (1991)
#
#
# #### p1 ####
# - The Godfather (1972)
# - Friends (1994)
# - The Shawshank Redemption (1994)
# - Seinfeld (1989)
# - Forrest Gump (1994)
# - The Simpsons (1989)
# - Pulp Fiction (1994)
# - The X-Files (1993)
# - Jurassic Park (1993)
# - The Fresh Prince of Bel-Air (1990)
# - The Silence of the Lambs (1991)
# - Twin Peaks (1990)
# - Schindler's List (1993)
# - Full House (1987)
# - Goodfellas (1990)
#
#
# #### p1 ####
# - The Shawshank Redemption (1994)
# - Friends (1994)
# - Pulp Fiction (1994)
# - The Matrix (1999)
# - The Sopranos (1999)
# - Forrest Gump (1994)
# - The X-Files (1993)
# - Jurassic Park (1993)
# - Seinfeld (1989)
# - The Silence of the Lambs (1991)
# - The Lion King (1994)
# - The Simpsons (1989)
# - Titanic (1997)
# - Breaking Bad (2008)
# - The Godfather (1972)
#
#
# #### p1 ####
# Casablanca (1942)
# The Shining (1980)
# Monty Python and the Holy Grail (1975)
# American Pie (1999)
# One Flew Over the Cuckoo's Nest (1975)
# The Fifth Element (1997)
# Willy Wonka & the Chocolate Factory (1971)
# American Beauty (1999)
# The Terminator (1984)
# Mad Max 2: The Road Warrior (1981)
# Much Ado About Nothing (1993)
# Beetlejuice (1988)
# Pee-wee's Big Adventure (1985)
# Dragonheart (1996)
# Assassins (1995)
#
#
# #### p1 ####
# The Shawshank Redemption (1994)
# Friends (1994)
# Forrest Gump (1994)
# The Lion King (1994)
# Pulp Fiction (1994)
# The X-Files (1993)
# Jurassic Park (1993)
# The Nightmare Before Christmas (1993)
# Schindler's List (1993)
# The Piano (1993)
# The Silence of the Lambs (1991)
# Twin Peaks (1990)
# Goodfellas (1990)
# Home Alone (1990)
# Edward Scissorhands (1990)
#
#
# #### p1 ####
# The Princess Bride (1987)
# Friends (1994)
# Forrest Gump (1994)
# The X-Files (1993)
# The Shawshank Redemption (1994)
# Seinfeld (1989)
# Jurassic Park (1993)
# The Simpsons (1989)
# The Silence of the Lambs (1991)
# The Fresh Prince of Bel-Air (1990)
# Pulp Fiction (1994)
# Full House (1987)
# Home Alone (1990)
# The Office (2005)
# Titanic (1997)
#
#
# #### p1 ####
# 1. The Godfather (1972)
# 2. Friends (1994)
# 3. Forrest Gump (1994)
# 4. The Shawshank Redemption (1994)
# 5. Seinfeld (1989)
# 6. Pulp Fiction (1994)
# 7. The Simpsons (1989)
# 8. Jurassic Park (1993)
# 9. The Matrix (1999)
# 10. Breaking Bad (2008)
# 11. The Silence of the Lambs (1991)
# 12. The Sopranos (1999)
# 13. Schindler's List (1993)
# 14. The X-Files (1993)
# 15. Goodfellas (1990)
#
#
# #### p1 ####
# The Princess Bride (1987)
# Friends (1994)
# Forrest Gump (1994)
# The X-Files (1993)
# The Godfather (1972)
# The Simpsons (1989)
# Jurassic Park (1993)
# Breaking Bad (2008)
# The Shawshank Redemption (1994)
# The Twilight Zone (1959)
# Pulp Fiction (1994)
# Seinfeld (1989)
# Back to the Future (1985)
# The Sopranos (1999)
# The Silence of the Lambs (1991)
#
#
# #### p1 ####
# - The Shawshank Redemption (1994)
# - Friends (1994)
# - Pulp Fiction (1994)
# - The Lion King (1994)
# - Forrest Gump (1994)
# - Seinfeld (1989)
# - Jurassic Park (1993)
# - The Matrix (1999)
# - The Silence of the Lambs (1991)
# - The Simpsons (1989)
# - The Godfather (1972)
# - Breaking Bad (2008)
# - Schindler's List (1993)
# - The Sopranos (1999)
# - The Green Mile (1999)
#
#
# #### p1 ####
# The Shawshank Redemption (1994)
# Friends (1994)
# Forrest Gump (1994)
# The Lion King (1994)
# Pulp Fiction (1994)
# The Matrix (1999)
# The Sopranos (1999)
# Fight Club (1999)
# The Sixth Sense (1999)
# The Office (UK) (2001)
# The Godfather (1972)
# Breaking Bad (2008)
# Schindler's List (1993)
# The Simpsons (1989)
# Jurassic Park (1993)
#
#
# #### p2 ####
# 1. The Matrix (1999)
# 2. Fight Club (1999)
# 3. The Sixth Sense (1999)
# 4. American Beauty (1999)
# 5. The Green Mile (1999)
# 6. The Shawshank Redemption (1994)
# 7. Pulp Fiction (1994)
# 8. Forrest Gump (1994)
# 9. Schindler's List (1993)
# 10. Jurassic Park (1993)
# 11. The Silence of the Lambs (1991)
# 12. Terminator 2: Judgment Day (1991)
# 13. Goodfellas (1990)
# 14. The Godfather Part II (1974)
# 15. Star Wars: Episode IV - A New Hope (1977)
#
#
# #### p2 ####
# The Shawshank Redemption (1994)
# Pulp Fiction (1994)
# The Matrix (1999)
# The Silence of the Lambs (1991)
# Forrest Gump (1994)
# The Godfather (1972)
# Schindler's List (1993)
# Fight Club (1999)
# The Green Mile (1999)
# The Sixth Sense (1999)
# The Sopranos (1999)
# Friends (1994)
# Breaking Bad (2008)
# The Office (2005)
# Lost (2004)
#
#
# #### p2 ####
# The recommendations are:
#
# 1. The Shawshank Redemption (1994)
# 2. Pulp Fiction (1994)
# 3. Forrest Gump (1994)
# 4. The Lion King (1994)
# 5. The Matrix (1999)
# 6. Fight Club (1999)
# 7. The Sixth Sense (1999)
# 8. American Beauty (1999)
# 9. The Green Mile (1999)
# 10. The Truman Show (1998)
# 11. Saving Private Ryan (1998)
# 12. The Big Lebowski (1998)
# 13. The Silence of the Lambs (1991)
# 14. Jurassic Park (1993)
# 15. Schindler's List (1993)
#
#
# #### p2 ####
# The Sixth Sense (1999)
# The Matrix (1999)
# Fight Club (1999)
# American Beauty (1999)
# The Green Mile (1999)
# The Blair Witch Project (1999)
# The Insider (1999)
# Being John Malkovich (1999)
# Eyes Wide Shut (1999)
# The Talented Mr. Ripley (1999)
# The Shawshank Redemption (1994)
# Pulp Fiction (1994)
# Forrest Gump (1994)
# The Lion King (1994)
# The Usual Suspects (1995)
#
#
# #### p2 ####
# The Matrix (1999)
# The Shawshank Redemption (1994)
# Pulp Fiction (1994)
# Forrest Gump (1994)
# The Silence of the Lambs (1991)
# Jurassic Park (1993)
# The Lion King (1994)
# Fight Club (1999)
# The Sixth Sense (1999)
# Braveheart (1995)
# Se7en (1995)
# Titanic (1997)
# Goodfellas (1990)
# The Green Mile (1999)
# Saving Private Ryan (1998)
#
#
# #### p2 ####
# The Godfather (1972)
# The Shawshank Redemption (1994)
# Pulp Fiction (1994)
# The Silence of the Lambs (1991)
# Forrest Gump (1994)
# Schindler's List (1993)
# The Matrix (1999)
# Goodfellas (1990)
# Jurassic Park (1993)
# The Lion King (1994)
# The Sixth Sense (1999)
# Fight Club (1999)
# Braveheart (1995)
# The Green Mile (1999)
# Saving Private Ryan (1998)
#
#
# #### p2 ####
# The Godfather (1972)
# Star Wars: Episode IV - A New Hope (1977)
# The Shawshank Redemption (1994)
# Pulp Fiction (1994)
# The Silence of the Lambs (1991)
# Forrest Gump (1994)
# The Matrix (1999)
# Jurassic Park (1993)
# The Lion King (1994)
# Fight Club (1999)
# The Sixth Sense (1999)
# Schindler's List (1993)
# Goodfellas (1990)
# The Green Mile (1999)
# Braveheart (1995)
#
#
# #### p2 ####
# The recommendations for movies and TV shows released prior to 2015 are:
#
# 1. The Shawshank Redemption (1994)
# 2. Pulp Fiction (1994)
# 3. Forrest Gump (1994)
# 4. The Matrix (1999)
# 5. Fight Club (1999)
# 6. The Silence of the Lambs (1991)
# 7. Se7en (1995)
# 8. The Lion King (1994)
# 9. Friends (TV Series) (1994-2004)
# 10. The Sopranos (TV Series) (1999-2007)
# 11. The Godfather (1972)
# 12. Schindler's List (1993)
# 13. Jurassic Park (1993)
# 14. The Usual Suspects (1995)
# 15. The X-Files (TV Series) (1993-2002)
#
#
# #### p2 ####
# The recommendations for movies and TV shows released prior to 2015 are:
#
# 1. The Shawshank Redemption (1994)
# 2. Pulp Fiction (1994)
# 3. Forrest Gump (1994)
# 4. The Lion King (1994)
# 5. Friends (TV Series) (1994)
# 6. Seinfeld (TV Series) (1989)
# 7. The Matrix (1999)
# 8. The Silence of the Lambs (1991)
# 9. Schindler's List (1993)
# 10. Jurassic Park (1993)
# 11. The Godfather (1972)
# 12. The Sopranos (TV Series) (1999)
# 13. The Usual Suspects (1995)
# 14. The X-Files (TV Series) (1993)
# 15. The Big Lebowski (1998)
#
#
# #### p2 ####
# The following are 15 movie and TV show recommendations released prior to 2015:
#
# 1. The Shawshank Redemption (1994)
# 2. Pulp Fiction (1994)
# 3. Forrest Gump (1994)
# 4. The Lion King (1994)
# 5. Friends (TV Series) (1994)
# 6. The Matrix (1999)
# 7. Fight Club (1999)
# 8. The Sopranos (TV Series) (1999)
# 9. The Sixth Sense (1999)
# 10. American Beauty (1999)
# 11. The Silence of the Lambs (1991)
# 12. Schindler's List (1993)
# 13. Jurassic Park (1993)
# 14. The Usual Suspects (1995)
# 15. Seinfeld (TV Series) (1989)
#
#
# #### p2 ####
# The recommendations for movies and TV shows released prior to 2015 are:
#
# 1. The Shawshank Redemption (1994)
# 2. Pulp Fiction (1994)
# 3. Forrest Gump (1994)
# 4. The Lion King (1994)
# 5. Friends (TV Series) (1994-2004)
# 6. Seinfeld (TV Series) (1989-1998)
# 7. The Matrix (1999)
# 8. The Silence of the Lambs (1991)
# 9. Jurassic Park (1993)
# 10. The Sopranos (TV Series) (1999-2007)
# 11. The Godfather (1972)
# 12. Schindler's List (1993)
# 13. The X-Files (TV Series) (1993-2002)
# 14. The Simpsons (TV Series) (1989-present)
# 15. The Usual Suspects (1995)
#
#
# #### p2 ####
# The recommendations for movies and TV shows released prior to 2015 are:
#
# 1. The Shawshank Redemption (1994)
# 2. Pulp Fiction (1994)
# 3. Forrest Gump (1994)
# 4. The Lion King (1994)
# 5. Friends (TV Series) (1994)
# 6. The Matrix (1999)
# 7. The Silence of the Lambs (1991)
# 8. Seinfeld (TV Series) (1989)
# 9. The Godfather (1972)
# 10. Jurassic Park (1993)
# 11. The Sopranos (TV Series) (1999)
# 12. Schindler's List (1993)
# 13. The Simpsons (TV Series) (1989)
# 14. Fight Club (1999)
# 15. The Usual Suspects (1995)
#
#
# #### p2 ####
# The recommendations for movies and TV shows released prior to 2015 are:
#
# 1. The Godfather (1972)
# 2. Star Wars: Episode IV - A New Hope (1977)
# 3. The Shawshank Redemption (1994)
# 4. Pulp Fiction (1994)
# 5. Forrest Gump (1994)
# 6. The Matrix (1999)
# 7. Schindler's List (1993)
# 8. The Silence of the Lambs (1991)
# 9. Jurassic Park (1993)
# 10. The Lion King (1994)
# 11. Friends (TV Series) (1994-2004)
# 12. Seinfeld (TV Series) (1989-1998)
# 13. The Sopranos (TV Series) (1999-2007)
# 14. The X-Files (TV Series) (1993-2002)
# 15. Breaking Bad (TV Series) (2008-2013)
#
#
# #### p2 ####
# The recommendations are:
#
# 1. The Shawshank Redemption (1994)
# 2. Pulp Fiction (1994)
# 3. Forrest Gump (1994)
# 4. The Lion King (1994)
# 5. Friends (TV Series) (1994)
# 6. The Matrix (1999)
# 7. The Sopranos (TV Series) (1999)
# 8. Fight Club (1999)
# 9. The Sixth Sense (1999)
# 10. The Office (UK) (TV Series) (2001)
# 11. The Lord of the Rings: The Fellowship of the Ring (2001)
# 12. Gladiator (2000)
# 13. The Green Mile (1999)
# 14. American Beauty (1999)
# 15. The Truman Show (1998)
#
#
# #### p2 ####
# The recommendations are:
#
# 1. The Shawshank Redemption (1994)
# 2. Pulp Fiction (1994)
# 3. Forrest Gump (1994)
# 4. The Lion King (1994)
# 5. Friends (TV Series) (1994)
# 6. The Matrix (1999)
# 7. The Sopranos (TV Series) (1999)
# 8. Fight Club (1999)
# 9. The Sixth Sense (1999)
# 10. The Office (UK) (TV Series) (2001)
# 11. The Godfather (1972)
# 12. Seinfeld (TV Series) (1989)
# 13. The Silence of the Lambs (1991)
# 14. Jurassic Park (1993)
# 15. The X-Files (TV Series) (1993)
#
#
# #### p3 ####
# The Shawshank Redemption (1994)
# Friends (1994)
# Pulp Fiction (1994)
# The Lion King (1994)
# Forrest Gump (1994)
# The Matrix (1999)
# The Sopranos (1999)
# Fight Club (1999)
# The Sixth Sense (1999)
# The Office (US) (2005)
#
#
# #### p3 ####
# The Shawshank Redemption (1994)
# Friends (1994)
# Pulp Fiction (1994)
# The X-Files (1993)
# Forrest Gump (1994)
# The Simpsons (1989)
# The Matrix (1999)
# The Sopranos (1999)
# Schindler's List (1993)
# Breaking Bad (2008)
#
#
# #### p3 ####
# The Shawshank Redemption (1994)
# Friends (1994)
# Forrest Gump (1994)
# The X-Files (1993)
# Pulp Fiction (1994)
# The Fresh Prince of Bel-Air (1990)
# The Matrix (1999)
# The Sopranos (1999)
# Fight Club (1999)
# The West Wing (1999)
#
#
# #### p3 ####
# Casablanca (1942)
# Shining, The (1980)
# Predator 2 (1990)
# Predator (1987)
# What's Eating Gilbert Grape (1993)
# French Kiss (1995)
# Walk in the Clouds, A (1995)
# Crow, The (1994)
# When a Man Loves a Woman (1994)
# Jumanji (1995)
# Hoop Dreams (1994)
# Bullets Over Broadway (1994)
# Jungle Book, The (1994)
# Paper, The (1994)
# Hellraiser: Bloodline (1996)
# Cemetery Man (Dellamorte Dellamore) (1994)
# Nightmare on Elm Street 4: The Dream Master, A (1988)
# Gremlins 2: The New Batch (1990)
# Invasion of the Body Snatchers (1956)
# Jaws 3-D (1983)
# Swamp Thing (1982)
# Little Shop of Horrors (1986)
# Fright Night (1985)
# Amityville: Dollhouse (1996)
#
#
# #### p3 ####
# Casablanca (1942)
# Shining, The (1980)
# Predator 2 (1990)
# Predator (1987)
# One Flew Over the Cuckoo's Nest (1975)
# Monty Python and the Holy Grail (1975)
# American Pie (1999)
# Fifth Element, The (1997)
# Spider-Man (2002)
# Shrek (2001)
#
#
# #### p3 ####
# Casablanca (1942)
# The Shining (1980)
# American Pie (1999)
# One Flew Over the Cuckoo's Nest (1975)
# The Fifth Element (1997)
# Monty Python and the Holy Grail (1975)
# Spider-Man (2002)
# Shrek (2001)
# The Incredibles (2004)
# The Curious Case of Benjamin Button (2008)
# Willy Wonka & the Chocolate Factory (1971)
# Much Ado About Nothing (1993)

# The Shawshank Redemption (1994)
# Pulp Fiction (1994)
# The Silence of the Lambs (1991)
# Fight Club (1999)
# Forrest Gump (1994)
# The Sopranos (1999)
# Breaking Bad (2008)
# Friends (1994)
# The Godfather (1972)
# Seinfeld (1989)
# The Simpsons (1989)
# Jurassic Park (1993)
# The X-Files (1993)
#
#
# #### p4 ####
# The recommendations for movies or TV shows released before 2015 are:
#
# 1. The Shawshank Redemption (1994)
# 2. Pulp Fiction (1994)
# 3. Forrest Gump (1994)
# 4. The Matrix (1999)
# 5. Fight Club (1999)
# 6. The Silence of the Lambs (1991)
# 7. Se7en (1995)
# 8. The Sixth Sense (1999)
# 9. Friends (TV Series) (1994-2004)
# 10. The Sopranos (TV Series) (1999-2007)
# 11. The Godfather (1972)
# 12. Schindler's List (1993)
# 13. The Lord of the Rings: The Fellowship of the Ring (2001)
# 14. The Simpsons (TV Series) (1989-present)
# 15. Breaking Bad (TV Series) (2008-2013)
#
#
# #### p4 ####
# The following are 15 movies or TV shows released before 2015 that you may enjoy:
#
# 1. The Shawshank Redemption (1994)
# 2. Friends (TV series) (1994-2004)
# 3. Pulp Fiction (1994)
# 4. The Matrix (1999)
# 5. The Sopranos (TV series) (1999-2007)
# 6. Forrest Gump (1994)
# 7. The Silence of the Lambs (1991)
# 8. Seinfeld (TV series) (1989-1998)
# 9. The Lion King (1994)
# 10. Titanic (1997)
# 11. The X-Files (TV series) (1993-2002)
# 12. Jurassic Park (1993)
# 13. The Godfather (1972)
# 14. Breaking Bad (TV series) (2008-2013)
# 15. The Lord of the Rings: The Fellowship of the Ring (2001)
#
#
# #### p4 ####
# The recommendations are:
# 1. The Shawshank Redemption (1994)
# 2. Forrest Gump (1994)
# 3. Pulp Fiction (1994)
# 4. The Matrix (1999)
# 5. Fight Club (1999)
# 6. The Sopranos (1999)
# 7. The Lord of the Rings: The Fellowship of the Ring (2001)
# 8. The Office (2005)
# 9. Friends (1994)
# 10. The Godfather (1972)
# 11. Seinfeld (1989)
# 12. The Silence of the Lambs (1991)
# 13. The Simpsons (1989)
# 14. The Dark Knight (2008)
# 15. Breaking Bad (2008)
#
#
# #### p4 ####
# The recommendations are:
# 1. The Shawshank Redemption (1994)
# 2. Friends (1994)
# 3. Pulp Fiction (1994)
# 4. The Matrix (1999)
# 5. The Sopranos (1999)
# 6. The Silence of the Lambs (1991)
# 7. Seinfeld (1989)
# 8. Forrest Gump (1994)
# 9. The Lion King (1994)
# 10. The X-Files (1993)
# 11. The Godfather (1972)
# 12. Breaking Bad (2008)
# 13. Jurassic Park (1993)
# 14. The Simpsons (1989)
# 15. Schindler's List (1993)
#
#
# #### p4 ####
# The recommendations are:
# 1. The Godfather (1972)
# 2. The Shawshank Redemption (1994)
# 3. Pulp Fiction (1994)
# 4. Forrest Gump (1994)
# 5. Schindler's List (1993)
# 6. The Silence of the Lambs (1991)
# 7. The Matrix (1999)
# 8. The Lion King (1994)
# 9. Fight Club (1999)
# 10. Jurassic Park (1993)
# 11. The Sopranos (1999)
# 12. Friends (1994)
# 13. Seinfeld (1989)
# 14. The Simpsons (1989)
# 15. Breaking Bad (2008)
#
#
# #### p4 ####
# 1. The Shawshank Redemption (1994)
# 2. Pulp Fiction (1994)
# 3. Forrest Gump (1994)
# 4. The Matrix (1999)
# 5. The Sopranos (1999)
# 6. The Silence of the Lambs (1991)
# 7. Friends (1994)
# 8. The Godfather (1972)
# 9. Seinfeld (1989)
# 10. The Lion King (1994)
# 11. The Simpsons (1989)
# 12. Schindler's List (1993)
# 13. Jurassic Park (1993)
# 14. The Big Lebowski (1998)
# 15. Fight Club (1999)
#
#
# #### p4 ####
# Here are 15 movies or TV shows released before 2015 that you may enjoy:
#
# 1. The Godfather (1972)
# 2. Pulp Fiction (1994)
# 3. The Shawshank Redemption (1994)
# 4. Forrest Gump (1994)
# 5. The Matrix (1999)
# 6. Friends (TV series) (1994-2004)
# 7. The Silence of the Lambs (1991)
# 8. Seinfeld (TV series) (1989-1998)
# 9. Jurassic Park (1993)
# 10. The Sopranos (TV series) (1999-2007)
# 11. Schindler's List (1993)
# 12. The Lion King (1994)
# 13. The X-Files (TV series) (1993-2002)
# 14. Braveheart (1995)
# 15. The Big Lebowski (1998)

# %% [markdown]
# I'll disqualify p3 and p4.
#
# - p4 output does not have a clear pattern: headers can be included or not. It'll be harder to adjust the returns.
#
# - p3 did not respected the amount of recs required.

# %% [markdown]
# ## 2.2 - Reading all movies names

# %%
movies_names = pd.read_csv(f"{PATH}/raw/movielens_20m_datasets/movie.csv")
movies_names.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %% [markdown]
# ## 2.3 - Functions

# %%
def item_is_relevant(user_id, item_id, df):
    aux = df[df["userId"] == user_id]
    if item_id in list(aux['title']):
        return True
    return False

# %%
def calculate_MAP(prediction_user_map, movies):

  progress_bar = tqdm(total=len(prediction_user_map), desc='Progress', position=0)
  MAP = 0

  for user_id in prediction_user_map:
    map_user, user_relevants = 0, 0
    for index, item in enumerate(prediction_user_map[user_id]):
      relevance = item_is_relevant(user_id, item, movies)
      user_relevants += int(relevance)
      map_user += user_relevants / (index + 1) if relevance else 0

    MAP += map_user / user_relevants if user_relevants != 0 else 0

    progress_bar.update(1)
  progress_bar.close()

  return round(MAP / len(prediction_user_map), 3)

# %%
def fix_response(response: str) -> list:
  # if it's an indexed list, I'll split and remove the integers
  if "." in response:
    movies = re.findall(r'\d+\.\s+(.+)', response)
    return movies
  else:
    pattern = r'((?:The\s)?(?:\b[A-Z][a-z]*\s?)+)\s\((\d{4})\)'
    movies = re.findall(pattern, response)
    movies = [f"{item} ({year})" for item, year in movies]

    return movies

# %%
# if the movie is not in IMDB dataset, the rec will be dropped
def in_dataset(user_interactions: str, all_movies):
  movies_in_dataset = [movie for movie in user_interactions if movie in list(all_movies.title)]

  return movies_in_dataset[:10]

# %% [markdown]
# ## 2.4 - Eval prompt 1

# %%
df_recs_a = df_recs[df_recs["prompt_id"] == "p1"]
df_recs_a.head(5)
# Out:
#   prompt_id                                           response  userId
# 0        p1  The Shawshank Redemption (1994)\nFriends (1994...     810
# 1        p1  The Princess Bride (1987)\nThe Shawshank Redem...     897
# 2        p1  The Sixth Sense (1999)\nThe Matrix (1999)\nAme...    1302
# 3        p1  The Godfather (1972)\nFriends (1994)\nForrest ...    1738
# 4        p1  The Godfather (1972)\nFriends (1994)\nThe Shaw...    1932

# %%
prediction_user_map_a = dict()

for index, row in df_recs_a.iterrows():
  movies = row['response']
  movies = fix_response(movies)
  movies = in_dataset(movies, movies_names)

  prediction_user_map_a[row["userId"]] = movies

# %%
prediction_user_map_a
# Out:
# {810: ['Pulp Fiction (1994)',
#   'Forrest Gump (1994)',
#   'American Beauty (1999)',
#   'Fight Club (1999)',
#   'Shrek (2001)'],
#  897: ['Forrest Gump (1994)',
#   'Pulp Fiction (1994)',
#   'Fight Club (1999)',
#   'Jurassic Park (1993)'],
#  1302: ['American Beauty (1999)',
#   'Fight Club (1999)',
#   'Pulp Fiction (1994)',
#   'Forrest Gump (1994)',
#   'Jurassic Park (1993)'],
#  1738: ['Forrest Gump (1994)',
#   'Pulp Fiction (1994)',
#   'Jurassic Park (1993)',
#   'Titanic (1997)',
#   'Braveheart (1995)',
#   'Home Alone (1990)'],
#  1932: ['Forrest Gump (1994)',
#   'Pulp Fiction (1994)',
#   'Jurassic Park (1993)',
#   'Titanic (1997)'],
#  1971: ['Forrest Gump (1994)',
#   'Jurassic Park (1993)',
#   'Home Alone (1990)',
#   'Pulp Fiction (1994)'],
#  2116: ['Forrest Gump (1994)',
#   'Pulp Fiction (1994)',
#   'Jurassic Park (1993)',
#   'Goodfellas (1990)'],
#  2162: ['Pulp Fiction (1994)',
#   'Forrest Gump (1994)',
#   'Jurassic Park (1993)',
#   'Titanic (1997)'],
#  2577: ['Casablanca (1942)',
#   'American Pie (1999)',
#   'American Beauty (1999)',
#   'Much Ado About Nothing (1993)',
#   'Beetlejuice (1988)',
#   'Dragonheart (1996)',
#   'Assassins (1995)'],
#  2675: ['Forrest Gump (1994)',
#   'Pulp Fiction (1994)',
#   'Jurassic Park (1993)',
#   'Goodfellas (1990)',
#   'Home Alone (1990)',
#   'Edward Scissorhands (1990)'],
#  2854: ['Forrest Gump (1994)',
#   'Jurassic Park (1993)',
#   'Pulp Fiction (1994)',
#   'Home Alone (1990)',
#   'Titanic (1997)'],
#  3231: ['Forrest Gump (1994)',
#   'Pulp Fiction (1994)',
#   'Jurassic Park (1993)',
#   "Schindler's List (1993)",
#   'Goodfellas (1990)'],
#  3300: ['Forrest Gump (1994)', 'Jurassic Park (1993)', 'Pulp Fiction (1994)'],
#  7623: ['Pulp Fiction (1994)', 'Forrest Gump (1994)', 'Jurassic Park (1993)'],
#  7886: ['Forrest Gump (1994)',
#   'Pulp Fiction (1994)',
#   'Fight Club (1999)',
#   'Jurassic Park (1993)']}

# %%
map_p1 = calculate_MAP(prediction_user_map_a, testset)
# Out:
# Progress: 100%|██████████| 15/15 [00:00<00:00, 693.91it/s]

# %% [markdown]
# ## 2.5 - Eval prompt 2

# %%
df_recs_b = df_recs[df_recs["prompt_id"] == "p2"]
df_recs_b.head(5)
# Out:
#    prompt_id                                           response  userId
# 15        p2  1. The Matrix (1999)\n2. Fight Club (1999)\n3....     810
# 16        p2  The Shawshank Redemption (1994)\nPulp Fiction ...     897
# 17        p2  The recommendations are:\n\n1. The Shawshank R...    1302
# 18        p2  The Sixth Sense (1999)\nThe Matrix (1999)\nFig...    1738
# 19        p2  The Matrix (1999)\nThe Shawshank Redemption (1...    1932

# %%
prediction_user_map_b = dict()

for index, row in df_recs_b.iterrows():
  movies = row['response']
  movies = fix_response(movies)
  movies = in_dataset(movies, movies_names)

  prediction_user_map_b[row["userId"]] = movies

# %%
prediction_user_map_b
# Out:
# {810: ['Fight Club (1999)',
#   'American Beauty (1999)',
#   'Pulp Fiction (1994)',
#   'Forrest Gump (1994)',
#   "Schindler's List (1993)",
#   'Jurassic Park (1993)',
#   'Terminator 2: Judgment Day (1991)',
#   'Goodfellas (1990)',
#   'Star Wars: Episode IV - A New Hope (1977)'],
#  897: ['Pulp Fiction (1994)', 'Forrest Gump (1994)', 'Fight Club (1999)'],
#  1302: ['Pulp Fiction (1994)',
#   'Forrest Gump (1994)',
#   'Fight Club (1999)',
#   'American Beauty (1999)',
#   'Saving Private Ryan (1998)',
#   'Jurassic Park (1993)',
#   "Schindler's List (1993)"],
#  1738: [],
#  1932: ['Pulp Fiction (1994)',
#   'Forrest Gump (1994)',
#   'Jurassic Park (1993)',
#   'Fight Club (1999)',
#   'Braveheart (1995)',
#   'Titanic (1997)',
#   'Goodfellas (1990)',
#   'Saving Private Ryan (1998)'],
#  1971: ['Pulp Fiction (1994)',
#   'Forrest Gump (1994)',
#   'Goodfellas (1990)',
#   'Jurassic Park (1993)',
#   'Fight Club (1999)',
#   'Braveheart (1995)',
#   'Saving Private Ryan (1998)'],
#  2116: ['Pulp Fiction (1994)',
#   'Forrest Gump (1994)',
#   'Jurassic Park (1993)',
#   'Fight Club (1999)',
#   'Goodfellas (1990)',
#   'Braveheart (1995)'],
#  2162: ['Pulp Fiction (1994)',
#   'Forrest Gump (1994)',
#   'Fight Club (1999)',
#   "Schindler's List (1993)",
#   'Jurassic Park (1993)'],
#  2577: ['Pulp Fiction (1994)',
#   'Forrest Gump (1994)',
#   "Schindler's List (1993)",
#   'Jurassic Park (1993)'],
#  2675: ['Pulp Fiction (1994)',
#   'Forrest Gump (1994)',
#   'Fight Club (1999)',
#   'American Beauty (1999)',
#   "Schindler's List (1993)",
#   'Jurassic Park (1993)'],
#  2854: ['Pulp Fiction (1994)',
#   'Forrest Gump (1994)',
#   'Jurassic Park (1993)',
#   "Schindler's List (1993)"],
#  3231: ['Pulp Fiction (1994)',
#   'Forrest Gump (1994)',
#   'Jurassic Park (1993)',
#   "Schindler's List (1993)",
#   'Fight Club (1999)'],
#  3300: ['Star Wars: Episode IV - A New Hope (1977)',
#   'Pulp Fiction (1994)',
#   'Forrest Gump (1994)',
#   "Schindler's List (1993)",
#   'Jurassic Park (1993)'],
#  7623: ['Pulp Fiction (1994)',
#   'Forrest Gump (1994)',
#   'Fight Club (1999)',
#   'Gladiator (2000)',
#   'American Beauty (1999)'],
#  7886: ['Pulp Fiction (1994)',
#   'Forrest Gump (1994)',
#   'Fight Club (1999)',
#   'Jurassic Park (1993)']}

# %%
map_p2 = calculate_MAP(prediction_user_map_b, testset)
# Out:
# Progress: 100%|██████████| 15/15 [00:00<00:00, 632.23it/s]

# %% [markdown]
# ## 2.6 -  Results

# %%
print(f"TEST 1\nMAP (prompt 1) = {map_p1}\nMAP (prompt 2) = {map_p2}")
# Out:
# TEST 1
# MAP (prompt 1) = 0.397
# MAP (prompt 2) = 0.525

# %% [markdown]
# ## 2.7 - How many recs were in the dataset?

# %%
test_1_total_recs_count = 0
for index, row in df_recs_a.iterrows():
  movies = row['response']
  movies = fix_response(movies)
  test_1_total_recs_count += len(movies)


test_1_total_recs_in_dataset_count = 0
for recs_in_dataset in prediction_user_map_a.values():
  test_1_total_recs_in_dataset_count += len(recs_in_dataset)

perc_1_a = round(test_1_total_recs_in_dataset_count/test_1_total_recs_count*100, 2)
print(f"PROMPT 1:\n{perc_1_a}% of the recs were in IMDB dataset")
# Out:
# PROMPT 1:
# 30.94% of the recs were in IMDB dataset

# %%
test_1_total_recs_count = 0
for index, row in df_recs_b.iterrows():
  movies = row['response']
  movies = fix_response(movies)
  test_1_total_recs_count += len(movies)


test_1_total_recs_in_dataset_count = 0
for recs_in_dataset in prediction_user_map_b.values():
  test_1_total_recs_in_dataset_count += len(recs_in_dataset)

perc_1_b = round(test_1_total_recs_in_dataset_count/test_1_total_recs_count*100, 2)
print(f"PROMPT 1:\n{perc_1_b}% of the recs were in IMDB dataset")
# Out:
# PROMPT 1:
# 37.32% of the recs were in IMDB dataset

# %% [markdown]
# # 3.0 - Refining Prompts

# %% [markdown]
# Based on the p1 and p2 results, I'll do a new request informing the dataset name thru the input

# %% [markdown]
# ## 3.1 - New requests

# %%
testing_prompts = {
  "p5": "Please suggest 15 movies or TV shows (based on the IMDB dataset). Format the output as follows: 'production (release year)\nproduction (release year)\nproduction (release year)...'",
  "p6": "I'm looking for movies and TV shows, can you provide 15 recommendations released prior to 2015 based on the IMDB dataset? Please list 15 productions with their release years only in the format: 'production (release year)\nproduction (release year)...'",
}

# %%
llm_recs = list()

total_iterations = len(testing_prompts) * len(user_movies_dict)
progress_bar = tqdm(total=total_iterations, desc='Progress')

for prompt_id, prompt in testing_prompts.items():
  for k, v in user_movies_dict.items():
    temp_dict = dict()

    movies = "\n".join(v)
    prompt += f"\nI've watched:\n{movies}"
    response = request_openai(prompt)

    temp_dict['prompt_id'] = prompt_id
    temp_dict["response"] = response
    temp_dict["userId"] = k

    llm_recs.append(temp_dict)
    progress_bar.update(1)

progress_bar.close()
# Out:
# Progress:  10%|█         | 3/30 [00:16<02:26,  5.44s/it]
# Progress: 100%|██████████| 30/30 [01:47<00:00,  3.59s/it]

# %%
df_recs = pd.DataFrame(llm_recs)
df_recs.tail(5)
# Out:
#    prompt_id                                           response  userId
# 25        p6  The recommendations based on the IMDB dataset ...    2854
# 26        p6  The Shawshank Redemption (1994)\nPulp Fiction ...    3231
# 27        p6  The Shawshank Redemption (1994)\nPulp Fiction ...    3300
# 28        p6  The Shawshank Redemption (1994)\nPulp Fiction ...    7623
# 29        p6  The recommendations based on the IMDB dataset ...    7886

# %% [markdown]
# ## 3.2 - Saving Recs

# %%
df_recs.to_csv(f"{PATH}/refined/recs_llm/evaluating_prompts_imdb_prompt.csv", index=False)

# %% [markdown]
# ## 3.3 - Visual Analysis

# %%
df_recs_c = df_recs[df_recs["prompt_id"] == "p5"]
df_recs_c.head(5)

# %%
df_recs_c = df_recs[df_recs["prompt_id"] == "p5"]
df_recs_c.head(5)

for response in df_recs_c.response:
  print(f"\n\n{response}")
# Out:
# 1. The Lord of the Rings: The Fellowship of the Ring (2001)
# 2. Harry Potter and the Sorcerer's Stone (2001)
# 3. Monsters, Inc. (2001)
# 4. Shrek (2001)
# 5. Spirited Away (2001)
# 6. Donnie Darko (2001)
# 7. A Beautiful Mind (2001)
# 8. Ocean's Eleven (2001)
# 9. Training Day (2001)
# 10. Black Hawk Down (2001)
# 11. The Royal Tenenbaums (2001)
# 12. Amélie (2001)
# 13. Mulholland Drive (2001)
# 14. The Others (2001)
# 15. Zoolander (2001)
#
#
# Based on the IMDB dataset, here are 15 movie and TV show recommendations for you:
#
# 1. The Lord of the Rings: The Fellowship of the Ring (2001)
# 2. Harry Potter and the Sorcerer's Stone (2001)
# 3. Shrek (2001)
# 4. Monsters, Inc. (2001)
# 5. Ocean's Eleven (2001)
# 6. Black Hawk Down (2001)
# 7. Training Day (2001)
# 8. The Office (2001-2003) - TV Series
# 9. 24 (2001-2010) - TV Series
# 10. Alias (2001-2006) - TV Series
# 11. Spirited Away (2001)
# 12. Donnie Darko (2001)
# 13. Mulholland Drive (2001)
# 14. The Others (2001)
# 15. The Royal Tenenbaums (2001)
#
#
# 1. The Lord of the Rings: The Fellowship of the Ring (2001)
# 2. Harry Potter and the Sorcerer's Stone (2001)
# 3. Shrek (2001)
# 4. Monsters, Inc. (2001)
# 5. Ocean's Eleven (2001)
# 6. Black Hawk Down (2001)
# 7. Training Day (2001)
# 8. Donnie Darko (2001)
# 9. The Others (2001)
# 10. Mulholland Drive (2001)
# 11. Spirited Away (2001)
# 12. The Royal Tenenbaums (2001)
# 13. A Beautiful Mind (2001)
# 14. The Pianist (2002)
# 15. Catch Me If You Can (2002)
#
#
# The Lord of the Rings: The Fellowship of the Ring (2001)
# The Office (2005)
# The Wire (2002)
# The Dark Knight (2008)
# Breaking Bad (2008)
# The Shawshank Redemption (1994)
# Pulp Fiction (1994)
# Fight Club (1999)
# The Matrix (1999)
# The Sopranos (1999)
# Inception (2010)
# The Godfather (1972)
# The Simpsons (1989)
# Friends (1994)
# The Avengers (2012)
#
#
# The Godfather (1972)
# The Shawshank Redemption (1994)
# The Dark Knight (2008)
# Schindler's List (1993)
# The Lord of the Rings: The Return of the King (2003)
# Pulp Fiction (1994)
# Fight Club (1999)
# Forrest Gump (1994)
# Inception (2010)
# The Matrix (1999)
# Goodfellas (1990)
# The Silence of the Lambs (1991)
# The Departed (2006)
# The Prestige (2006)
# The Green Mile (1999)
#
#
# 1. The Lord of the Rings: The Fellowship of the Ring (2001)
# 2. Harry Potter and the Sorcerer's Stone (2001)
# 3. Shrek (2001)
# 4. Monsters, Inc. (2001)
# 5. Ocean's Eleven (2001)
# 6. Spirited Away (2001)
# 7. Black Hawk Down (2001)
# 8. Training Day (2001)
# 9. Donnie Darko (2001)
# 10. The Others (2001)
# 11. Mulholland Drive (2001)
# 12. A Beautiful Mind (2001)
# 13. The Royal Tenenbaums (2001)
# 14. Moulin Rouge! (2001)
# 15. A.I. Artificial Intelligence (2001)
#
#
# Casablanca (1942)
# Shining, The (1980)
# AVP: Alien vs. Predator (2004)
# Predator 2 (1990)
# Predator (1987)
# American Pie (1999)
# One Flew Over the Cuckoo's Nest (1975)
# Fifth Element, The (1997)
# Monty Python and the Holy Grail (1975)
# Spider-Man (2002)
# Shrek (2001)
# Incredibles, The (2004)
# Curious Case of Benjamin Button, The (2008)
# Slumdog Millionaire (2008)
# Terminator Salvation (2009)
#
#
# 1. The Lord of the Rings: The Fellowship of the Ring (2001)
# 2. Spirited Away (2001)
# 3. Monsters, Inc. (2001)
# 4. Donnie Darko (2001)
# 5. Training Day (2001)
# 6. Black Hawk Down (2001)
# 7. The Royal Tenenbaums (2001)
# 8. Ocean's Eleven (2001)
# 9. Shrek (2001)
# 10. Mulholland Drive (2001)
# 11. The Pianist (2002)
# 12. City of God (2002)
# 13. Catch Me If You Can (2002)
# 14. Adaptation. (2002)
# 15. The Ring (2002)
#
#
# Based on the IMDB dataset, here are 15 movie or TV show recommendations for you:
#
# 1. The Dark Knight (2008)
# 2. Breaking Bad (2008-2013)
# 3. The Shawshank Redemption (1994)
# 4. Game of Thrones (2011-2019)
# 5. Pulp Fiction (1994)
# 6. Stranger Things (2016- )
# 7. The Godfather (1972)
# 8. Friends (1994-2004)
# 9. The Matrix (1999)
# 10. The Office (2005-2013)
# 11. Inception (2010)
# 12. Black Mirror (2011- )
# 13. Forrest Gump (1994)
# 14. Sherlock (2010-2017)
# 15. Interstellar (2014)
#
#
# Based on the IMDB dataset, here are 15 movie or TV show recommendations for you:
#
# 1. The Lord of the Rings: The Fellowship of the Ring (2001)
# 2. Spirited Away (2001)
# 3. Monsters, Inc. (2001)
# 4. Donnie Darko (2001)
# 5. Mulholland Drive (2001)
# 6. The Office (2001)
# 7. Band of Brothers (2001)
# 8. Black Hawk Down (2001)
# 9. Training Day (2001)
# 10. Ocean's Eleven (2001)
# 11. The Pianist (2002)
# 12. City of God (2002)
# 13. Catch Me If You Can (2002)
# 14. Adaptation. (2002)
# 15. 28 Days Later... (2002)
#
#
# Based on the IMDB dataset, here are 15 movie or TV show recommendations for you:
#
# 1. The Dark Knight (2008)
# 2. The Shawshank Redemption (1994)
# 3. Breaking Bad (2008-2013)
# 4. Pulp Fiction (1994)
# 5. The Godfather (1972)
# 6. The Matrix (1999)
# 7. Friends (1994-2004)
# 8. Inception (2010)
# 9. Game of Thrones (2011-2019)
# 10. Fight Club (1999)
# 11. Stranger Things (2016-present)
# 12. The Lord of the Rings: The Fellowship of the Ring (2001)
# 13. The Office (2005-2013)
# 14. The Avengers (2012)
# 15. Black Mirror (2011-present)
#
#
# Based on the IMDB dataset, here are 15 movie or TV show recommendations for you:
#
# 1. The Dark Knight (2008)
# 2. The Shawshank Redemption (1994)
# 3. Pulp Fiction (1994)
# 4. The Godfather (1972)
# 5. The Matrix (1999)
# 6. Forrest Gump (1994)
# 7. Fight Club (1999)
# 8. Inception (2010)
# 9. The Lord of the Rings: The Return of the King (2003)
# 10. The Silence of the Lambs (1991)
# 11. The Departed (2006)
# 12. The Prestige (2006)
# 13. The Green Mile (1999)
# 14. Gladiator (2000)
# 15. The Usual Suspects (1995)
#
#
# 1. The Lord of the Rings: The Fellowship of the Ring (2001)
# 2. Spirited Away (2001)
# 3. The Office (2005)
# 4. The Wire (2002)
# 5. The Dark Knight (2008)
# 6. The Prestige (2006)
# 7. Gladiator (2000)
# 8. The Departed (2006)
# 9. Avatar (2009)
# 10. The Shawshank Redemption (1994)
# 11. Inception (2010)
# 12. Breaking Bad (2008)
# 13. The Matrix (1999)
# 14. Friends (1994)
# 15. Pulp Fiction (1994)
#
#
# 1. The Shawshank Redemption (1994)
# 2. The Godfather (1972)
# 3. The Dark Knight (2008)
# 4. The Lord of the Rings: The Return of the King (2003)
# 5. Pulp Fiction (1994)
# 6. Schindler's List (1993)
# 7. The Lord of the Rings: The Fellowship of the Ring (2001)
# 8. Fight Club (1999)
# 9. Forrest Gump (1994)
# 10. Inception (2010)
# 11. The Matrix (1999)
# 12. The Silence of the Lambs (1991)
# 13. The Usual Suspects (1995)
# 14. Se7en (1995)
# 15. The Prestige (2006)
#
#
# 1. The Lord of the Rings: The Fellowship of the Ring (2001)
# 2. Spirited Away (2001)
# 3. Monsters, Inc. (2001)
# 4. Donnie Darko (2001)
# 5. Black Hawk Down (2001)
# 6. Training Day (2001)
# 7. Shrek (2001)
# 8. A Beautiful Mind (2001)
# 9. Ocean's Eleven (2001)
# 10. Mulholland Drive (2001)
# 11. The Office (2005)
# 12. Grey's Anatomy (2005)
# 13. Prison Break (2005)
# 14. Supernatural (2005)
# 15. It's Always Sunny in Philadelphia (2005)

# %%
df_recs_d = df_recs[df_recs["prompt_id"] == "p6"]
df_recs_d.head(5)

for response in df_recs_d.response:
  print(f"\n\n{response}")
# Out:
# The recommendations based on the IMDB dataset released prior to 2015 are:
#
# 1. The Shawshank Redemption (1994)
# 2. The Godfather (1972)
# 3. The Dark Knight (2008)
# 4. Schindler's List (1993)
# 5. The Lord of the Rings: The Return of the King (2003)
# 6. Pulp Fiction (1994)
# 7. Fight Club (1999)
# 8. Forrest Gump (1994)
# 9. Inception (2010)
# 10. The Matrix (1999)
# 11. The Silence of the Lambs (1991)
# 12. The Green Mile (1999)
# 13. The Departed (2006)
# 14. Gladiator (2000)
# 15. The Prestige (2006)
#
#
# The recommendations based on the IMDB dataset released prior to 2015 are:
#
# 1. The Shawshank Redemption (1994)
# 2. The Godfather (1972)
# 3. The Dark Knight (2008)
# 4. Pulp Fiction (1994)
# 5. Schindler's List (1993)
# 6. The Lord of the Rings: The Return of the King (2003)
# 7. Fight Club (1999)
# 8. Forrest Gump (1994)
# 9. The Matrix (1999)
# 10. Goodfellas (1990)
# 11. The Silence of the Lambs (1991)
# 12. Se7en (1995)
# 13. The Usual Suspects (1995)
# 14. The Green Mile (1999)
# 15. Gladiator (2000)
#
#
# The recommendations based on the IMDB dataset released prior to 2015 are:
#
# 1. The Shawshank Redemption (1994)
# 2. Pulp Fiction (1994)
# 3. Forrest Gump (1994)
# 4. The Lion King (1994)
# 5. The Matrix (1999)
# 6. Schindler's List (1993)
# 7. The Silence of the Lambs (1991)
# 8. The Green Mile (1999)
# 9. Fight Club (1999)
# 10. The Sixth Sense (1999)
# 11. Goodfellas (1990)
# 12. The Usual Suspects (1995)
# 13. Se7en (1995)
# 14. Saving Private Ryan (1998)
# 15. The Truman Show (1998)
#
#
# Casablanca (1942)
# Shining, The (1980)
# Predator 2 (1990)
# Predator (1987)
# Evolution (2001)
# Lara Croft: Tomb Raider (2001)
# Bridget Jones's Diary (2001)
# Along Came a Spider (2001)
# Blow (2001)
# Josie and the Pussycats (2001)
# Knight's Tale, A (2001)
# Moulin Rouge (2001)
# Pearl Harbor (2001)
# Good Will Hunting (1997)
# Hellraiser: Bloodline (1996)
#
#
# The recommendations based on the IMDB dataset released prior to 2015 are:
#
# 1. The Shawshank Redemption (1994)
# 2. The Godfather (1972)
# 3. The Dark Knight (2008)
# 4. Schindler's List (1993)
# 5. The Lord of the Rings: The Return of the King (2003)
# 6. Pulp Fiction (1994)
# 7. Fight Club (1999)
# 8. Forrest Gump (1994)
# 9. The Matrix (1999)
# 10. Goodfellas (1990)
# 11. The Silence of the Lambs (1991)
# 12. The Lion King (1994)
# 13. Saving Private Ryan (1998)
# 14. The Green Mile (1999)
# 15. Gladiator (2000)
#
#
# The recommendations based on the IMDB dataset released prior to 2015 are:
#
# 1. The Shawshank Redemption (1994)
# 2. The Godfather (1972)
# 3. The Dark Knight (2008)
# 4. Pulp Fiction (1994)
# 5. Schindler's List (1993)
# 6. The Lord of the Rings: The Return of the King (2003)
# 7. Fight Club (1999)
# 8. Forrest Gump (1994)
# 9. The Matrix (1999)
# 10. Goodfellas (1990)
# 11. The Silence of the Lambs (1991)
# 12. Se7en (1995)
# 13. The Usual Suspects (1995)
# 14. The Lion King (1994)
# 15. Gladiator (2000)
#
#
# The recommendations based on the IMDB dataset released prior to 2015 are:
#
# 1. The Shawshank Redemption (1994)
# 2. The Godfather (1972)
# 3. The Dark Knight (2008)
# 4. Schindler's List (1993)
# 5. Pulp Fiction (1994)
# 6. The Lord of the Rings: The Return of the King (2003)
# 7. Fight Club (1999)
# 8. Forrest Gump (1994)
# 9. The Matrix (1999)
# 10. Goodfellas (1990)
# 11. Star Wars: Episode V - The Empire Strikes Back (1980)
# 12. The Silence of the Lambs (1991)
# 13. Se7en (1995)
# 14. Gladiator (2000)
# 15. The Usual Suspects (1995)
#
#
# The following are 15 movie and TV show recommendations released prior to 2015 based on the IMDB dataset:
#
# 1. The Shawshank Redemption (1994)
# 2. The Godfather (1972)
# 3. The Dark Knight (2008)
# 4. Schindler's List (1993)
# 5. The Lord of the Rings: The Return of the King (2003)
# 6. Pulp Fiction (1994)
# 7. The Matrix (1999)
# 8. Forrest Gump (1994)
# 9. Fight Club (1999)
# 10. Goodfellas (1990)
# 11. The Silence of the Lambs (1991)
# 12. Se7en (1995)
# 13. The Usual Suspects (1995)
# 14. The Sixth Sense (1999)
# 15. Gladiator (2000)
#
#
# The Shawshank Redemption (1994)
# The Godfather (1972)
# The Dark Knight (2008)
# The Godfather: Part II (1974)
# 12 Angry Men (1957)
# Schindler's List (1993)
# The Lord of the Rings: The Return of the King (2003)
# Pulp Fiction (1994)
# The Good, the Bad and the Ugly (1966)
# Fight Club (1999)
# Forrest Gump (1994)
# Inception (2010)
# The Lord of the Rings: The Fellowship of the Ring (2001)
# The Matrix (1999)
# The Silence of the Lambs (1991)
#
#
# The Shawshank Redemption (1994)
# The Godfather (1972)
# The Dark Knight (2008)
# The Godfather: Part II (1974)
# The Lord of the Rings: The Return of the King (2003)
# Pulp Fiction (1994)
# Schindler's List (1993)
# 12 Angry Men (1957)
# The Good, the Bad and the Ugly (1966)
# Fight Club (1999)
# Forrest Gump (1994)
# Inception (2010)
# The Matrix (1999)
# Goodfellas (1990)
# The Silence of the Lambs (1991)
#
#
# The recommendations based on the IMDB dataset released prior to 2015 are:
#
# 1. The Shawshank Redemption (1994)
# 2. The Godfather (1972)
# 3. The Dark Knight (2008)
# 4. Pulp Fiction (1994)
# 5. Schindler's List (1993)
# 6. The Lord of the Rings: The Return of the King (2003)
# 7. Fight Club (1999)
# 8. Forrest Gump (1994)
# 9. Inception (2010)
# 10. The Matrix (1999)
# 11. Goodfellas (1990)
# 12. The Silence of the Lambs (1991)
# 13. The Usual Suspects (1995)
# 14. Se7en (1995)
# 15. The Lion King (1994)
#
#
# The Shawshank Redemption (1994)
# Pulp Fiction (1994)
# The Godfather (1972)
# The Dark Knight (2008)
# 12 Angry Men (1957)
# Schindler's List (1993)
# The Lord of the Rings: The Return of the King (2003)
# Fight Club (1999)
# Forrest Gump (1994)
# Inception (2010)
# The Matrix (1999)
# Goodfellas (1990)
# The Silence of the Lambs (1991)
# The Usual Suspects (1995)
# The Green Mile (1999)
#
#
# The Shawshank Redemption (1994)
# Pulp Fiction (1994)
# The Matrix (1999)
# The Silence of the Lambs (1991)
# Forrest Gump (1994)
# The Lion King (1994)
# The Godfather (1972)
# The Dark Knight (2008)
# Fight Club (1999)
# Schindler's List (1993)
# Goodfellas (1990)
# The Green Mile (1999)
# The Usual Suspects (1995)
# Se7en (1995)
# The Sixth Sense (1999)
#
#
# The Shawshank Redemption (1994)
# Pulp Fiction (1994)
# The Matrix (1999)
# The Silence of the Lambs (1991)
# Fight Club (1999)
# Forrest Gump (1994)
# The Godfather (1972)
# The Dark Knight (2008)
# The Lord of the Rings: The Return of the King (2003)
# The Lord of the Rings: The Fellowship of the Ring (2001)
# The Lord of the Rings: The Two Towers (2002)
# The Usual Suspects (1995)
# Se7en (1995)
# Gladiator (2000)
#
#
# The recommendations based on the IMDB dataset released prior to 2015 are:
#
# 1. The Shawshank Redemption (1994)
# 2. The Godfather (1972)
# 3. The Dark Knight (2008)
# 4. Schindler's List (1993)
# 5. The Lord of the Rings: The Return of the King (2003)
# 6. Pulp Fiction (1994)
# 7. Forrest Gump (1994)
# 8. Fight Club (1999)
# 9. Inception (2010)
# 10. The Matrix (1999)
# 11. Goodfellas (1990)
# 12. The Silence of the Lambs (1991)
# 13. The Usual Suspects (1995)
# 14. Se7en (1995)
# 15. Gladiator (2000)

# %% [markdown]
# ## 3.4 - Eval prompt 5

# %%
prediction_user_map_c = dict()

for index, row in df_recs_c.iterrows():
  movies = row['response']
  movies = fix_response(movies)
  movies = in_dataset(movies, movies_names)

  prediction_user_map_c[row["userId"]] = movies

# %%
map_p5 = calculate_MAP(prediction_user_map_c, testset)
# Out:
# Progress: 100%|██████████| 15/15 [00:00<00:00, 627.02it/s]

# %% [markdown]
# ## 3.5 - Eval prompt 6

# %%
prediction_user_map_d = dict()

for index, row in df_recs_d.iterrows():
  movies = row['response']
  movies = fix_response(movies)
  movies = in_dataset(movies, movies_names)

  prediction_user_map_d[row["userId"]] = movies

# %%
map_p6 = calculate_MAP(prediction_user_map_d, testset)
# Out:
# Progress: 100%|██████████| 15/15 [00:00<00:00, 572.32it/s]

# %% [markdown]
# ## 3.6 - Results

# %%
print(f"TEST 2\nMAP (prompt 5) = {map_p5}\nMAP (prompt 6) = {map_p6}")
# Out:
# TEST 2
# MAP (prompt 5) = 0.267
# MAP (prompt 6) = 0.5

# %% [markdown]
# ## 3.7 - How many recs were in the dataset?

# %%
test_2_total_recs_count = 0
for index, row in df_recs_c.iterrows():
  movies = row['response']
  movies = fix_response(movies)
  test_2_total_recs_count += len(movies)


test_2_total_recs_in_dataset_count = 0
for recs_in_dataset in prediction_user_map_c.values():
  test_2_total_recs_in_dataset_count += len(recs_in_dataset)

perc_2_c = round(test_2_total_recs_in_dataset_count/test_2_total_recs_count*100, 2)
print(f"PROMPT 5:\n{perc_2_c}% of the recs were in IMDB dataset")
# Out:
# PROMPT 5:
# 39.52% of the recs were in IMDB dataset

# %%
test_2_total_recs_count = 0
for index, row in df_recs_d.iterrows():
  movies = row['response']
  movies = fix_response(movies)
  test_2_total_recs_count += len(movies)


test_2_total_recs_in_dataset_count = 0
for recs_in_dataset in prediction_user_map_d.values():
  test_2_total_recs_in_dataset_count += len(recs_in_dataset)

perc_2_d = round(test_2_total_recs_in_dataset_count/test_2_total_recs_count*100, 2)
print(f"PROMPT 6:\n{perc_2_d}% of the recs were in IMDB dataset")
# Out:
# PROMPT 6:
# 39.27% of the recs were in IMDB dataset
